# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

import math

# %%
def scale_factor_K(b, s, p_exit):
    return (1 - b) * (1 - s) / (1 - s - p_exit)

# %%
def p_exit(md, H):
    mdr = 1 / md
    int_H = math.exp(-mdr * H) * (mdr**2 * H * (H - 4) + 2 * mdr * (H - 2) + 2)
    int_0 = 2 - (4 * mdr)
    return (int_H - int_0) / mdr**2 / math.pi

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D # This import has side effects required for the kwarg projection='3d' in the call to fig.add_subplot

# %%
p_ex = p_exit(3, 1)
p_ex
# Out:
# 0.14285168214004282

# %%
fig = plt.figure(figsize=(12,9))
ax = fig.add_subplot(111, projection='3d')

b = np.arange(0.01, 0.05, 0.001)
s = np.arange(0.01, 0.05, 0.001)
B, S = np.meshgrid(b, s)
Ks = np.array([scale_factor_K(b,s,p_ex) for b,s in zip(np.ravel(B), np.ravel(S))])
K = Ks.reshape(B.shape)

ax.plot_surface(B, S, K)

ax.set_xlabel('b')
ax.set_ylabel('s')
ax.set_zlabel('K')

plt.show()

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)

BS = s
K = np.array([scale_factor_K(bs,bs,p_ex) for bs in BS])
ax.plot(BS, K)
ax.set_xlabel("b=s")
ax.set_ylabel("K")
plt.show()

# %%
p_buffer = (K * p_ex) / (K * p_ex + (1 - 0.72) * (1 - 0.72))
p_buffer
# Out:
# array([0.67825452, 0.67641207, 0.67454975, 0.67266727, 0.67076437,
#        0.66884077, 0.66689618, 0.66493034, 0.66294295, 0.66093374,
#        0.65890243, 0.65684873, 0.65477237, 0.65267306, 0.65055052,
#        0.64840449, 0.64623467, 0.64404082, 0.64182266, 0.63957993,
#        0.6373124 , 0.6350198 , 0.63270191, 0.63035852, 0.62798942,
#        0.6255944 , 0.62317331, 0.62072599, 0.61825232, 0.61575218,
#        0.61322552, 0.61067229, 0.6080925 , 0.6054862 , 0.60285349,
#        0.60019451, 0.5975095 , 0.59479875, 0.59206264, 0.58930163,
#        0.58651631, 0.58370738, 0.58087567, 0.57802217, 0.57514805,
#        0.57225468, 0.56934367, 0.56641687, 0.56347646, 0.56052493,
#        0.55756521, 0.55460064, 0.55163512, 0.54867316, 0.54571996,
#        0.54278157, 0.53986502, 0.53697844, 0.53413134, 0.53133482,
#        0.52860188, 0.52594778, 0.52339054, 0.52095151, 0.51865607,
#        0.51653462, 0.51462372, 0.51296768, 0.51162059, 0.51064904,
# ...

# %%
plt.plot(K, p_buffer)

# %%
b=0.03
s=0.03
K_ = scale_factor_K(b, s, p_ex)
pB = (K_ * p_ex) / (K_ * p_ex + (1 - b) * (1 - s))
p_ex, K_, pB
# Out:
# (0.14285168214004282, 1.137522714710159, 0.147269775402106)
